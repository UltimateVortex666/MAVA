# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
df=pd.read_csv("C:\\Users\\Ankan Dutta\\Desktop\\DTI\\datasets\\dataset 14-20.csv")

# %%
df
# Out:
#                   Title                Director  \
# 0    Mr Joe B. Carvalho            Samir Tiwari
# 1             Sholay 3D            Ramesh Sippy
# 2          Dedh Ishqiya       Abhishek Chaubey_
# 3              Yaariyan      Divya Khosla Kumar
# 4      Karle Pyaar Kade           Rajesh Pandey
# ..                  ...                     ...
# 500      Fukrey Returns   Mrighdeep Singh Lamba
# 501           Game Over  Paresh Vinodray Savani
# 502     Sallu Ki Shaadi   Mohammad Israr Ansari
# 503    Monsoon Shootout              Amit Kumar
# 504     Tiger Zinda Hai         Ali Abbas Zafar
#
#                                                   Cast                  Genre  \
# 0    Arshad Warsi, Soha Ali Khan, Javed Jaffrey, Vi...                 Comedy
# 1    Dharmendra, Amitabh Bachchan, Hema Malini, Jay...       Action/Adventure
# 2    Naseeruddin Shah, Arshad Warsi, Madhuri Dixit,...  Black Comedy/Thriller
# 3    Himansh Kohli, Shreyas Pardiwalla, Dev Sharma,...                Romance
# 4                           Shiv Darshan, Hasleen Kaur                Romance
# ..                                                 ...                    ...
# 500  Pulkit Samrat, Priya Anand, Ali Fazal, Varun S...                 Comedy
# 501      Rajesh Sharma, Yashpal Sharma, Gurleen Chopra      Suspense/thriller
# 502  Zeenat Aman, Kiran Kumar, Asrani, Kshayp, Arsh...           Comedy drama
# 503  Nawazuddin Siddiqui, Vijay Varma & Tannishtha ...         Crime/thriller
# 504                         Salman Khan & Katrina Kaif           Action/drama
#
#     Unnamed: 4
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 500        NaN
# 501        NaN
# 502        NaN
# 503        NaN
# 504        NaN
#
# [505 rows x 5 columns]

# %%
df_hin = df[['Title','Director','Cast','Genre']]

# %%
df_hin
# Out:
#                   Title                Director  \
# 0    Mr Joe B. Carvalho            Samir Tiwari
# 1             Sholay 3D            Ramesh Sippy
# 2          Dedh Ishqiya       Abhishek Chaubey_
# 3              Yaariyan      Divya Khosla Kumar
# 4      Karle Pyaar Kade           Rajesh Pandey
# ..                  ...                     ...
# 500      Fukrey Returns   Mrighdeep Singh Lamba
# 501           Game Over  Paresh Vinodray Savani
# 502     Sallu Ki Shaadi   Mohammad Israr Ansari
# 503    Monsoon Shootout              Amit Kumar
# 504     Tiger Zinda Hai         Ali Abbas Zafar
#
#                                                   Cast                  Genre
# 0    Arshad Warsi, Soha Ali Khan, Javed Jaffrey, Vi...                 Comedy
# 1    Dharmendra, Amitabh Bachchan, Hema Malini, Jay...       Action/Adventure
# 2    Naseeruddin Shah, Arshad Warsi, Madhuri Dixit,...  Black Comedy/Thriller
# 3    Himansh Kohli, Shreyas Pardiwalla, Dev Sharma,...                Romance
# 4                           Shiv Darshan, Hasleen Kaur                Romance
# ..                                                 ...                    ...
# 500  Pulkit Samrat, Priya Anand, Ali Fazal, Varun S...                 Comedy
# 501      Rajesh Sharma, Yashpal Sharma, Gurleen Chopra      Suspense/thriller
# 502  Zeenat Aman, Kiran Kumar, Asrani, Kshayp, Arsh...           Comedy drama
# 503  Nawazuddin Siddiqui, Vijay Varma & Tannishtha ...         Crime/thriller
# 504                         Salman Khan & Katrina Kaif           Action/drama
#
# [505 rows x 4 columns]

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in c:\users\ankan dutta\appdata\local\programs\python\python311\lib\site-packages (1.7.7)
# Requirement already satisfied: requests in c:\users\ankan dutta\appdata\local\programs\python\python311\lib\site-packages (from tmdbv3api) (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ankan dutta\appdata\local\programs\python\python311\lib\site-packages (from requests->tmdbv3api) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ankan dutta\appdata\local\programs\python\python311\lib\site-packages (from requests->tmdbv3api) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ankan dutta\appdata\local\programs\python\python311\lib\site-packages (from requests->tmdbv3api) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ankan dutta\appdata\local\programs\python\python311\lib\site-packages (from requests->tmdbv3api) (2022.12.7)
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '28a4d63a51fd003a26ae5b50b3d0832d'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_hin
# Out:
#                   Title                Director  \
# 0    Mr Joe B. Carvalho            Samir Tiwari
# 1             Sholay 3D            Ramesh Sippy
# 2          Dedh Ishqiya       Abhishek Chaubey_
# 3              Yaariyan      Divya Khosla Kumar
# 4      Karle Pyaar Kade           Rajesh Pandey
# ..                  ...                     ...
# 500      Fukrey Returns   Mrighdeep Singh Lamba
# 501           Game Over  Paresh Vinodray Savani
# 502     Sallu Ki Shaadi   Mohammad Israr Ansari
# 503    Monsoon Shootout              Amit Kumar
# 504     Tiger Zinda Hai         Ali Abbas Zafar
#
#                                                   Cast                  Genre
# 0    Arshad Warsi, Soha Ali Khan, Javed Jaffrey, Vi...                 Comedy
# 1    Dharmendra, Amitabh Bachchan, Hema Malini, Jay...       Action/Adventure
# 2    Naseeruddin Shah, Arshad Warsi, Madhuri Dixit,...  Black Comedy/Thriller
# 3    Himansh Kohli, Shreyas Pardiwalla, Dev Sharma,...                Romance
# 4                           Shiv Darshan, Hasleen Kaur                Romance
# ..                                                 ...                    ...
# 500  Pulkit Samrat, Priya Anand, Ali Fazal, Varun S...                 Comedy
# 501      Rajesh Sharma, Yashpal Sharma, Gurleen Chopra      Suspense/thriller
# 502  Zeenat Aman, Kiran Kumar, Asrani, Kshayp, Arsh...           Comedy drama
# 503  Nawazuddin Siddiqui, Vijay Varma & Tannishtha ...         Crime/thriller
# 504                         Salman Khan & Katrina Kaif           Action/drama
#
# [505 rows x 4 columns]

# %%
df_hin = df_hin.rename(columns={'Director':'director_name'})

# %%
df_hin = df_hin.rename(columns={'Genre':'genres'})

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_hin['actor_1_name'] = df_hin['Cast'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_hin['actor_2_name'] = df_hin['Cast'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_hin['actor_3_name'] = df_hin['Cast'].map(lambda x: get_actor3(str(x)))

# %%
df_hin
# Out:
#                   Title           director_name  \
# 0    Mr Joe B. Carvalho            Samir Tiwari
# 1             Sholay 3D            Ramesh Sippy
# 2          Dedh Ishqiya       Abhishek Chaubey_
# 3              Yaariyan      Divya Khosla Kumar
# 4      Karle Pyaar Kade           Rajesh Pandey
# ..                  ...                     ...
# 500      Fukrey Returns   Mrighdeep Singh Lamba
# 501           Game Over  Paresh Vinodray Savani
# 502     Sallu Ki Shaadi   Mohammad Israr Ansari
# 503    Monsoon Shootout              Amit Kumar
# 504     Tiger Zinda Hai         Ali Abbas Zafar
#
#                                                   Cast                 genres  \
# 0    Arshad Warsi, Soha Ali Khan, Javed Jaffrey, Vi...                 Comedy
# 1    Dharmendra, Amitabh Bachchan, Hema Malini, Jay...       Action/Adventure
# 2    Naseeruddin Shah, Arshad Warsi, Madhuri Dixit,...  Black Comedy/Thriller
# 3    Himansh Kohli, Shreyas Pardiwalla, Dev Sharma,...                Romance
# 4                           Shiv Darshan, Hasleen Kaur                Romance
# ..                                                 ...                    ...
# 500  Pulkit Samrat, Priya Anand, Ali Fazal, Varun S...                 Comedy
# 501      Rajesh Sharma, Yashpal Sharma, Gurleen Chopra      Suspense/thriller
# 502  Zeenat Aman, Kiran Kumar, Asrani, Kshayp, Arsh...           Comedy drama
# 503  Nawazuddin Siddiqui, Vijay Varma & Tannishtha ...         Crime/thriller
# 504                         Salman Khan & Katrina Kaif           Action/drama
#
#                    actor_1_name                         actor_2_name  \
# 0                  Arshad Warsi                        Soha Ali Khan
# 1                    Dharmendra                     Amitabh Bachchan
# 2              Naseeruddin Shah                         Arshad Warsi
# 3                 Himansh Kohli                   Shreyas Pardiwalla
# 4                  Shiv Darshan                         Hasleen Kaur
# ..                          ...                                  ...
# 500               Pulkit Samrat                          Priya Anand
# 501               Rajesh Sharma                       Yashpal Sharma
# 502                 Zeenat Aman                          Kiran Kumar
# 503         Nawazuddin Siddiqui  Vijay Varma & Tannishtha Chatterjee
# 504  Salman Khan & Katrina Kaif                                  NaN
#
#        actor_3_name
# 0     Javed Jaffrey
# 1       Hema Malini
# 2     Madhuri Dixit
# 3        Dev Sharma
# 4               NaN
# ..              ...
# 500       Ali Fazal
# 501  Gurleen Chopra
# 502          Asrani
# 503             NaN
# 504             NaN
#
# [505 rows x 7 columns]

# %%
df_hin = df_hin.rename(columns={'Title':'movie_title'})

# %%
new_df = df_hin.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df
# Out:
#               director_name                actor_1_name  \
# 0              Samir Tiwari                Arshad Warsi
# 1              Ramesh Sippy                  Dharmendra
# 2         Abhishek Chaubey_            Naseeruddin Shah
# 3        Divya Khosla Kumar               Himansh Kohli
# 4             Rajesh Pandey                Shiv Darshan
# ..                      ...                         ...
# 500   Mrighdeep Singh Lamba               Pulkit Samrat
# 501  Paresh Vinodray Savani               Rajesh Sharma
# 502   Mohammad Israr Ansari                 Zeenat Aman
# 503              Amit Kumar         Nawazuddin Siddiqui
# 504         Ali Abbas Zafar  Salman Khan & Katrina Kaif
#
#                             actor_2_name    actor_3_name  \
# 0                          Soha Ali Khan   Javed Jaffrey
# 1                       Amitabh Bachchan     Hema Malini
# 2                           Arshad Warsi   Madhuri Dixit
# 3                     Shreyas Pardiwalla      Dev Sharma
# 4                           Hasleen Kaur             NaN
# ..                                   ...             ...
# 500                          Priya Anand       Ali Fazal
# 501                       Yashpal Sharma  Gurleen Chopra
# 502                          Kiran Kumar          Asrani
# 503  Vijay Varma & Tannishtha Chatterjee             NaN
# 504                                  NaN             NaN
#
#                     genres         movie_title
# 0                   Comedy  Mr Joe B. Carvalho
# 1         Action/Adventure           Sholay 3D
# 2    Black Comedy/Thriller        Dedh Ishqiya
# 3                  Romance            Yaariyan
# 4                  Romance    Karle Pyaar Kade
# ..                     ...                 ...
# 500                 Comedy      Fukrey Returns
# 501      Suspense/thriller           Game Over
# 502           Comedy drama     Sallu Ki Shaadi
# 503         Crime/thriller    Monsoon Shootout
# 504           Action/drama     Tiger Zinda Hai
#
# [505 rows x 6 columns]

# %%
print(new_df.dtypes)
# Out:
# director_name    object
# actor_1_name     object
# actor_2_name     object
# actor_3_name     object
# genres           object
# movie_title      object
# dtype: object

# %%
for column in ['actor_1_name', 'actor_2_name', 'actor_3_name', 'director_name', 'genres']:
    for i in range(len(new_df)):
        new_df.at[i, column] = str(new_df.at[i, column])

new_df['comb'] = new_df['actor_1_name'] + ' ' + new_df['actor_2_name'] + ' ' + new_df['actor_3_name'] + ' ' + new_df['director_name'] + ' ' + new_df['genres']

# %%
print(new_df.dtypes)
# Out:
# director_name    object
# actor_1_name     object
# actor_2_name     object
# actor_3_name     object
# genres           object
# movie_title      object
# comb             object
# dtype: object

# %%
new_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      5
# comb             0
# dtype: int64

# %%
new_df22 = new_df.dropna(how='any')

# %%
new_df22.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df22['movie_title'] = new_df22['movie_title'].str.lower()
# Out:
# C:\Users\Ankan Dutta\AppData\Local\Temp\ipykernel_28548\2732328091.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df22['movie_title'] = new_df22['movie_title'].str.lower()

# %%
new_df22
# Out:
#               director_name                actor_1_name  \
# 0              Samir Tiwari                Arshad Warsi
# 1              Ramesh Sippy                  Dharmendra
# 2         Abhishek Chaubey_            Naseeruddin Shah
# 3        Divya Khosla Kumar               Himansh Kohli
# 4             Rajesh Pandey                Shiv Darshan
# ..                      ...                         ...
# 500   Mrighdeep Singh Lamba               Pulkit Samrat
# 501  Paresh Vinodray Savani               Rajesh Sharma
# 502   Mohammad Israr Ansari                 Zeenat Aman
# 503              Amit Kumar         Nawazuddin Siddiqui
# 504         Ali Abbas Zafar  Salman Khan & Katrina Kaif
#
#                             actor_2_name    actor_3_name  \
# 0                          Soha Ali Khan   Javed Jaffrey
# 1                       Amitabh Bachchan     Hema Malini
# 2                           Arshad Warsi   Madhuri Dixit
# 3                     Shreyas Pardiwalla      Dev Sharma
# 4                           Hasleen Kaur             nan
# ..                                   ...             ...
# 500                          Priya Anand       Ali Fazal
# 501                       Yashpal Sharma  Gurleen Chopra
# 502                          Kiran Kumar          Asrani
# 503  Vijay Varma & Tannishtha Chatterjee             nan
# 504                                  nan             nan
#
#                     genres         movie_title  \
# 0                   Comedy  mr joe b. carvalho
# 1         Action/Adventure           sholay 3d
# 2    Black Comedy/Thriller        dedh ishqiya
# 3                  Romance            yaariyan
# 4                  Romance    karle pyaar kade
# ..                     ...                 ...
# 500                 Comedy      fukrey returns
# 501      Suspense/thriller           game over
# 502           Comedy drama     sallu ki shaadi
# 503         Crime/thriller    monsoon shootout
# 504           Action/drama     tiger zinda hai
#
#                                                   comb
# 0    Arshad Warsi Soha Ali Khan Javed Jaffrey Samir...
# 1    Dharmendra Amitabh Bachchan Hema Malini Ramesh...
# 2    Naseeruddin Shah Arshad Warsi Madhuri Dixit Ab...
# 3    Himansh Kohli Shreyas Pardiwalla Dev Sharma Di...
# 4    Shiv Darshan Hasleen Kaur nan Rajesh Pandey Ro...
# ..                                                 ...
# 500  Pulkit Samrat Priya Anand Ali Fazal Mrighdeep ...
# 501  Rajesh Sharma Yashpal Sharma Gurleen Chopra Pa...
# 502  Zeenat Aman Kiran Kumar Asrani Mohammad Israr ...
# 503  Nawazuddin Siddiqui Vijay Varma & Tannishtha C...
# 504  Salman Khan & Katrina Kaif nan nan Ali Abbas Z...
#
# [500 rows x 7 columns]

# %%
old_df = pd.read_csv('C:\\Users\\Ankan Dutta\\Desktop\\DTI\\datasets\\main_data.csv')

# %%
old_df
# Out:
#           director_name     actor_1_name        actor_2_name  \
# 0         James Cameron      CCH Pounder    Joel David Moore
# 1        Gore Verbinski      Johnny Depp       Orlando Bloom
# 2            Sam Mendes  Christoph Waltz        Rory Kinnear
# 3     Christopher Nolan        Tom Hardy      Christian Bale
# 4           Doug Walker      Doug Walker          Rob Walker
# ...                 ...              ...                 ...
# 8512  Dharan Mandarayar  Sonali Kulkarni        Amardeep Jha
# 8513         Mohit Suri   Kangana Ranaut        Shiney Ahuja
# 8514   Nasseruddin Shah     Ayesha Takia  Konkona Sen Sharma
# 8515       Sanjay Gupta      Sanjay Dutt        John Abraham
# 8516     Tanuja Chandra     Sushmita Sen        Shiney Ahuja
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 8512        Shameem Shaikh                            Drama
# 8513                   NaN           Drama, Romance, Social
# 8514          Paresh Rawal                            Drama
# 8515            Lara Dutta                         Thriller
# 8516                   NaN                            Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 8512                                      white rainbow
# 8513                                       woh lamhe...
# 8514                              yun hota toh kya hota
# 8515                                              zinda
# 8516                                     zindaggi rocks
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 8512  Sonali Kulkarni Amardeep Jha Shameem Shaikh Dh...
# 8513  Kangana Ranaut Shiney Ahuja nan Mohit Suri Dra...
# 8514  Ayesha Takia Konkona Sen Sharma Paresh Rawal N...
# 8515  Sanjay Dutt John Abraham Lara Dutta Sanjay Gup...
# 8516  Sushmita Sen Shiney Ahuja nan Tanuja Chandra D...
#
# [8517 rows x 7 columns]

# %%
final_df = old_df.append(new_df22,ignore_index=True)
# Out:
# C:\Users\Ankan Dutta\AppData\Local\Temp\ipykernel_28548\1166909226.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = old_df.append(new_df22,ignore_index=True)

# %%
final_df
# Out:
#                director_name                actor_1_name  \
# 0              James Cameron                 CCH Pounder
# 1             Gore Verbinski                 Johnny Depp
# 2                 Sam Mendes             Christoph Waltz
# 3          Christopher Nolan                   Tom Hardy
# 4                Doug Walker                 Doug Walker
# ...                      ...                         ...
# 9012   Mrighdeep Singh Lamba               Pulkit Samrat
# 9013  Paresh Vinodray Savani               Rajesh Sharma
# 9014   Mohammad Israr Ansari                 Zeenat Aman
# 9015              Amit Kumar         Nawazuddin Siddiqui
# 9016         Ali Abbas Zafar  Salman Khan & Katrina Kaif
#
#                              actor_2_name          actor_3_name  \
# 0                        Joel David Moore             Wes Studi
# 1                           Orlando Bloom        Jack Davenport
# 2                            Rory Kinnear      Stephanie Sigman
# 3                          Christian Bale  Joseph Gordon-Levitt
# 4                              Rob Walker               unknown
# ...                                   ...                   ...
# 9012                          Priya Anand             Ali Fazal
# 9013                       Yashpal Sharma        Gurleen Chopra
# 9014                          Kiran Kumar                Asrani
# 9015  Vijay Varma & Tannishtha Chatterjee                   nan
# 9016                                  nan                   nan
#
#                                genres  \
# 0     Action Adventure Fantasy Sci-Fi
# 1            Action Adventure Fantasy
# 2           Action Adventure Thriller
# 3                     Action Thriller
# 4                         Documentary
# ...                               ...
# 9012                           Comedy
# 9013                Suspense/thriller
# 9014                     Comedy drama
# 9015                   Crime/thriller
# 9016                     Action/drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 9012                                     fukrey returns
# 9013                                          game over
# 9014                                    sallu ki shaadi
# 9015                                   monsoon shootout
# 9016                                    tiger zinda hai
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 9012  Pulkit Samrat Priya Anand Ali Fazal Mrighdeep ...
# 9013  Rajesh Sharma Yashpal Sharma Gurleen Chopra Pa...
# 9014  Zeenat Aman Kiran Kumar Asrani Mohammad Israr ...
# 9015  Nawazuddin Siddiqui Vijay Varma & Tannishtha C...
# 9016  Salman Khan & Katrina Kaif nan nan Ali Abbas Z...
#
# [9017 rows x 7 columns]

# %%
final_df.to_csv('C:\\Users\\Ankan Dutta\\Desktop\\DTI\\datasets\\main_data.csv',index=False)
