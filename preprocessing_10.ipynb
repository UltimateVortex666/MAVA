# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
df=pd.read_csv("C:\\Users\\Ankan Dutta\\Desktop\\DTI\\datasets\\dataset.csv")

# %%
df
# Out:
#                   Title                                           Director  \
# 0                  1921                                       Vikram Bhatt
# 1           Kaalakaandi                                       Akshat Verma
# 2             Mukkabaaz                                     Anurag Kashyap
# 3              PhirSe..                                        Kunal Kohli
# 4      My Birthday Song                                         Samir Soni
# ..                  ...                                                ...
# 331  Omprakash Zindabad                                      Ranjeet Gupta
# 332            Unpaused  Raj & D.K Nitya Mehra Nikkhil Advani , Tannish...
# 333            AK vs AK                               Vikramaditya Motwane
# 334        Coolie No. 1                                       David Dhawan
# 335            Shakeela                                   Indrajit Lankesh
#
#                                                   Cast
# 0    Zareen Khan, Karan Kundra, Tobby Hinston,Sonia...
# 1    Saif Ali Khan, Isha Talwar, Shenaz Treasury, A...
# 2    Vineet Kumar Singh, Zoya Hussain, Ravi Kishan,...
# 3            Jennifer Winget, Kunal Kohli, Rajit Kapur
# 4                   Sanjay Suri, Nora Fatehi, Pitobash
# ..                                                 ...
# 331  Kulbhushan Kharbanda , Jagdeep , Shweta Bhardw...
# 332  Gulshan Devaiah , Sumeet Vyas , Saiyami Kher ,...
# 333                       Anil Kapoor , Anurag Kashyap
# 334                       Varun Dhawan , Sara Ali Khan
# 335     Richa Chadda , Pankaj Tripathi , Rajeev Pillai
#
# [336 rows x 3 columns]

# %%
df_hin = df[['Title','Director','Cast']]

# %%
df_hin
# Out:
#                   Title                                           Director  \
# 0                  1921                                       Vikram Bhatt
# 1           Kaalakaandi                                       Akshat Verma
# 2             Mukkabaaz                                     Anurag Kashyap
# 3              PhirSe..                                        Kunal Kohli
# 4      My Birthday Song                                         Samir Soni
# ..                  ...                                                ...
# 331  Omprakash Zindabad                                      Ranjeet Gupta
# 332            Unpaused  Raj & D.K Nitya Mehra Nikkhil Advani , Tannish...
# 333            AK vs AK                               Vikramaditya Motwane
# 334        Coolie No. 1                                       David Dhawan
# 335            Shakeela                                   Indrajit Lankesh
#
#                                                   Cast
# 0    Zareen Khan, Karan Kundra, Tobby Hinston,Sonia...
# 1    Saif Ali Khan, Isha Talwar, Shenaz Treasury, A...
# 2    Vineet Kumar Singh, Zoya Hussain, Ravi Kishan,...
# 3            Jennifer Winget, Kunal Kohli, Rajit Kapur
# 4                   Sanjay Suri, Nora Fatehi, Pitobash
# ..                                                 ...
# 331  Kulbhushan Kharbanda , Jagdeep , Shweta Bhardw...
# 332  Gulshan Devaiah , Sumeet Vyas , Saiyami Kher ,...
# 333                       Anil Kapoor , Anurag Kashyap
# 334                       Varun Dhawan , Sara Ali Khan
# 335     Richa Chadda , Pankaj Tripathi , Rajeev Pillai
#
# [336 rows x 3 columns]

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in c:\users\ankan dutta\appdata\local\programs\python\python311\lib\site-packages (1.7.7)
# Requirement already satisfied: requests in c:\users\ankan dutta\appdata\local\programs\python\python311\lib\site-packages (from tmdbv3api) (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ankan dutta\appdata\local\programs\python\python311\lib\site-packages (from requests->tmdbv3api) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ankan dutta\appdata\local\programs\python\python311\lib\site-packages (from requests->tmdbv3api) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ankan dutta\appdata\local\programs\python\python311\lib\site-packages (from requests->tmdbv3api) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ankan dutta\appdata\local\programs\python\python311\lib\site-packages (from requests->tmdbv3api) (2022.12.7)
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '28a4d63a51fd003a26ae5b50b3d0832d'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_hin['genres'] = df_hin['Title'].map(lambda x: get_genre(str(x)))

# %%
df_hin
# Out:
#                   Title                                           Director  \
# 0                  1921                                       Vikram Bhatt
# 1           Kaalakaandi                                       Akshat Verma
# 2             Mukkabaaz                                     Anurag Kashyap
# 3              PhirSe..                                        Kunal Kohli
# 4      My Birthday Song                                         Samir Soni
# ..                  ...                                                ...
# 331  Omprakash Zindabad                                      Ranjeet Gupta
# 332            Unpaused  Raj & D.K Nitya Mehra Nikkhil Advani , Tannish...
# 333            AK vs AK                               Vikramaditya Motwane
# 334        Coolie No. 1                                       David Dhawan
# 335            Shakeela                                   Indrajit Lankesh
#
#                                                   Cast  \
# 0    Zareen Khan, Karan Kundra, Tobby Hinston,Sonia...
# 1    Saif Ali Khan, Isha Talwar, Shenaz Treasury, A...
# 2    Vineet Kumar Singh, Zoya Hussain, Ravi Kishan,...
# 3            Jennifer Winget, Kunal Kohli, Rajit Kapur
# 4                   Sanjay Suri, Nora Fatehi, Pitobash
# ..                                                 ...
# 331  Kulbhushan Kharbanda , Jagdeep , Shweta Bhardw...
# 332  Gulshan Devaiah , Sumeet Vyas , Saiyami Kher ,...
# 333                       Anil Kapoor , Anurag Kashyap
# 334                       Varun Dhawan , Sara Ali Khan
# 335     Richa Chadda , Pankaj Tripathi , Rajeev Pillai
#
#                         genres
# 0                History Drama
# 1        Comedy Thriller Drama
# 2                        Drama
# 3                          NaN
# 4                     Thriller
# ..                         ...
# 331                        NaN
# 332               Comedy Drama
# 333  Comedy Action Drama Crime
# 334               Comedy Drama
# 335              Drama Romance
#
# [336 rows x 4 columns]

# %%
df_hin = df_hin.rename(columns={'Director':'director_name'})

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_hin['actor_1_name'] = df_hin['Cast'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_hin['actor_2_name'] = df_hin['Cast'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_hin['actor_3_name'] = df_hin['Cast'].map(lambda x: get_actor3(str(x)))

# %%
df_hin
# Out:
#                   Title                                      director_name  \
# 0                  1921                                       Vikram Bhatt
# 1           Kaalakaandi                                       Akshat Verma
# 2             Mukkabaaz                                     Anurag Kashyap
# 3              PhirSe..                                        Kunal Kohli
# 4      My Birthday Song                                         Samir Soni
# ..                  ...                                                ...
# 331  Omprakash Zindabad                                      Ranjeet Gupta
# 332            Unpaused  Raj & D.K Nitya Mehra Nikkhil Advani , Tannish...
# 333            AK vs AK                               Vikramaditya Motwane
# 334        Coolie No. 1                                       David Dhawan
# 335            Shakeela                                   Indrajit Lankesh
#
#                                                   Cast  \
# 0    Zareen Khan, Karan Kundra, Tobby Hinston,Sonia...
# 1    Saif Ali Khan, Isha Talwar, Shenaz Treasury, A...
# 2    Vineet Kumar Singh, Zoya Hussain, Ravi Kishan,...
# 3            Jennifer Winget, Kunal Kohli, Rajit Kapur
# 4                   Sanjay Suri, Nora Fatehi, Pitobash
# ..                                                 ...
# 331  Kulbhushan Kharbanda , Jagdeep , Shweta Bhardw...
# 332  Gulshan Devaiah , Sumeet Vyas , Saiyami Kher ,...
# 333                       Anil Kapoor , Anurag Kashyap
# 334                       Varun Dhawan , Sara Ali Khan
# 335     Richa Chadda , Pankaj Tripathi , Rajeev Pillai
#
#                         genres           actor_1_name      actor_2_name  \
# 0                History Drama            Zareen Khan      Karan Kundra
# 1        Comedy Thriller Drama          Saif Ali Khan       Isha Talwar
# 2                        Drama     Vineet Kumar Singh      Zoya Hussain
# 3                          NaN        Jennifer Winget       Kunal Kohli
# 4                     Thriller            Sanjay Suri       Nora Fatehi
# ..                         ...                    ...               ...
# 331                        NaN  Kulbhushan Kharbanda           Jagdeep
# 332               Comedy Drama       Gulshan Devaiah       Sumeet Vyas
# 333  Comedy Action Drama Crime           Anil Kapoor     Anurag Kashyap
# 334               Comedy Drama          Varun Dhawan      Sara Ali Khan
# 335              Drama Romance          Richa Chadda   Pankaj Tripathi
#
#                       actor_3_name
# 0    Tobby Hinston,Sonia Armstrong
# 1                  Shenaz Treasury
# 2                      Ravi Kishan
# 3                      Rajit Kapur
# 4                         Pitobash
# ..                             ...
# 331               Shweta Bhardwaj
# 332                  Saiyami Kher
# 333                            NaN
# 334                            NaN
# 335                  Rajeev Pillai
#
# [336 rows x 7 columns]

# %%
df_hin = df_hin.rename(columns={'Title':'movie_title'})

# %%
new_df = df_hin.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df
# Out:
#                                          director_name           actor_1_name  \
# 0                                         Vikram Bhatt            Zareen Khan
# 1                                         Akshat Verma          Saif Ali Khan
# 2                                       Anurag Kashyap     Vineet Kumar Singh
# 3                                          Kunal Kohli        Jennifer Winget
# 4                                           Samir Soni            Sanjay Suri
# ..                                                 ...                    ...
# 331                                      Ranjeet Gupta  Kulbhushan Kharbanda
# 332  Raj & D.K Nitya Mehra Nikkhil Advani , Tannish...       Gulshan Devaiah
# 333                               Vikramaditya Motwane           Anil Kapoor
# 334                                       David Dhawan          Varun Dhawan
# 335                                   Indrajit Lankesh          Richa Chadda
#
#          actor_2_name                   actor_3_name  \
# 0        Karan Kundra  Tobby Hinston,Sonia Armstrong
# 1         Isha Talwar                Shenaz Treasury
# 2        Zoya Hussain                    Ravi Kishan
# 3         Kunal Kohli                    Rajit Kapur
# 4         Nora Fatehi                       Pitobash
# ..                ...                            ...
# 331          Jagdeep                Shweta Bhardwaj
# 332      Sumeet Vyas                   Saiyami Kher
# 333    Anurag Kashyap                            NaN
# 334     Sara Ali Khan                            NaN
# 335  Pankaj Tripathi                   Rajeev Pillai
#
#                         genres         movie_title
# 0                History Drama                1921
# 1        Comedy Thriller Drama         Kaalakaandi
# 2                        Drama           Mukkabaaz
# 3                          NaN            PhirSe..
# 4                     Thriller    My Birthday Song
# ..                         ...                 ...
# 331                        NaN  Omprakash Zindabad
# 332               Comedy Drama            Unpaused
# 333  Comedy Action Drama Crime            AK vs AK
# 334               Comedy Drama        Coolie No. 1
# 335              Drama Romance            Shakeela
#
# [336 rows x 6 columns]

# %%
print(new_df.dtypes)
# Out:
# director_name    object
# actor_1_name     object
# actor_2_name     object
# actor_3_name     object
# genres           object
# movie_title      object
# dtype: object

# %%
for column in ['actor_1_name', 'actor_2_name', 'actor_3_name', 'director_name', 'genres']:
    for i in range(len(new_df)):
        new_df.at[i, column] = str(new_df.at[i, column])

new_df['comb'] = new_df['actor_1_name'] + ' ' + new_df['actor_2_name'] + ' ' + new_df['actor_3_name'] + ' ' + new_df['director_name'] + ' ' + new_df['genres']

# %%
new_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      4
# comb             0
# dtype: int64

# %%
new_df22 = new_df.dropna(how='any')

# %%
new_df22.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df22['movie_title'] = new_df22['movie_title'].str.lower()
# Out:
# C:\Users\Ankan Dutta\AppData\Local\Temp\ipykernel_23236\2732328091.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df22['movie_title'] = new_df22['movie_title'].str.lower()

# %%
new_df22
# Out:
#                                          director_name           actor_1_name  \
# 0                                         Vikram Bhatt            Zareen Khan
# 1                                         Akshat Verma          Saif Ali Khan
# 2                                       Anurag Kashyap     Vineet Kumar Singh
# 3                                          Kunal Kohli        Jennifer Winget
# 4                                           Samir Soni            Sanjay Suri
# ..                                                 ...                    ...
# 331                                      Ranjeet Gupta  Kulbhushan Kharbanda
# 332  Raj & D.K Nitya Mehra Nikkhil Advani , Tannish...       Gulshan Devaiah
# 333                               Vikramaditya Motwane           Anil Kapoor
# 334                                       David Dhawan          Varun Dhawan
# 335                                   Indrajit Lankesh          Richa Chadda
#
#          actor_2_name                   actor_3_name  \
# 0        Karan Kundra  Tobby Hinston,Sonia Armstrong
# 1         Isha Talwar                Shenaz Treasury
# 2        Zoya Hussain                    Ravi Kishan
# 3         Kunal Kohli                    Rajit Kapur
# 4         Nora Fatehi                       Pitobash
# ..                ...                            ...
# 331          Jagdeep                Shweta Bhardwaj
# 332      Sumeet Vyas                   Saiyami Kher
# 333    Anurag Kashyap                            nan
# 334     Sara Ali Khan                            nan
# 335  Pankaj Tripathi                   Rajeev Pillai
#
#                         genres         movie_title  \
# 0                History Drama                1921
# 1        Comedy Thriller Drama         kaalakaandi
# 2                        Drama           mukkabaaz
# 3                          nan            phirse..
# 4                     Thriller    my birthday song
# ..                         ...                 ...
# 331                        nan  omprakash zindabad
# 332               Comedy Drama            unpaused
# 333  Comedy Action Drama Crime            ak vs ak
# 334               Comedy Drama        coolie no. 1
# 335              Drama Romance            shakeela
#
#                                                   comb
# 0    Zareen Khan Karan Kundra Tobby Hinston,Sonia A...
# 1    Saif Ali Khan Isha Talwar Shenaz Treasury Aksh...
# 2    Vineet Kumar Singh Zoya Hussain Ravi Kishan An...
# 3    Jennifer Winget Kunal Kohli Rajit Kapur Kunal ...
# 4    Sanjay Suri Nora Fatehi Pitobash Samir Soni Th...
# ..                                                 ...
# 331  Kulbhushan Kharbanda  Jagdeep  Shweta Bhardwaj...
# 332  Gulshan Devaiah  Sumeet Vyas  Saiyami Kher  Ra...
# 333  Anil Kapoor  Anurag Kashyap nan Vikramaditya M...
# 334  Varun Dhawan  Sara Ali Khan nan David Dhawan C...
# 335  Richa Chadda  Pankaj Tripathi  Rajeev Pillai I...
#
# [332 rows x 7 columns]

# %%
old_df = pd.read_csv('C:\\Users\\Ankan Dutta\\Desktop\\DTI\\datasets\\main_data.csv')

# %%
old_df
# Out:
#                director_name                actor_1_name  \
# 0              James Cameron                 CCH Pounder
# 1             Gore Verbinski                 Johnny Depp
# 2                 Sam Mendes             Christoph Waltz
# 3          Christopher Nolan                   Tom Hardy
# 4                Doug Walker                 Doug Walker
# ...                      ...                         ...
# 9012   Mrighdeep Singh Lamba               Pulkit Samrat
# 9013  Paresh Vinodray Savani               Rajesh Sharma
# 9014   Mohammad Israr Ansari                 Zeenat Aman
# 9015              Amit Kumar         Nawazuddin Siddiqui
# 9016         Ali Abbas Zafar  Salman Khan & Katrina Kaif
#
#                              actor_2_name          actor_3_name  \
# 0                        Joel David Moore             Wes Studi
# 1                           Orlando Bloom        Jack Davenport
# 2                            Rory Kinnear      Stephanie Sigman
# 3                          Christian Bale  Joseph Gordon-Levitt
# 4                              Rob Walker               unknown
# ...                                   ...                   ...
# 9012                          Priya Anand             Ali Fazal
# 9013                       Yashpal Sharma        Gurleen Chopra
# 9014                          Kiran Kumar                Asrani
# 9015  Vijay Varma & Tannishtha Chatterjee                   NaN
# 9016                                  NaN                   NaN
#
#                                genres  \
# 0     Action Adventure Fantasy Sci-Fi
# 1            Action Adventure Fantasy
# 2           Action Adventure Thriller
# 3                     Action Thriller
# 4                         Documentary
# ...                               ...
# 9012                           Comedy
# 9013                Suspense/thriller
# 9014                     Comedy drama
# 9015                   Crime/thriller
# 9016                     Action/drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 9012                                     fukrey returns
# 9013                                          game over
# 9014                                    sallu ki shaadi
# 9015                                   monsoon shootout
# 9016                                    tiger zinda hai
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 9012  Pulkit Samrat Priya Anand Ali Fazal Mrighdeep ...
# 9013  Rajesh Sharma Yashpal Sharma Gurleen Chopra Pa...
# 9014  Zeenat Aman Kiran Kumar Asrani Mohammad Israr ...
# 9015  Nawazuddin Siddiqui Vijay Varma & Tannishtha C...
# 9016  Salman Khan & Katrina Kaif nan nan Ali Abbas Z...
#
# [9017 rows x 7 columns]

# %%
final_df = old_df.append(new_df22,ignore_index=True)
# Out:
# C:\Users\Ankan Dutta\AppData\Local\Temp\ipykernel_23236\1166909226.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = old_df.append(new_df22,ignore_index=True)

# %%
final_df
# Out:
#                                           director_name  \
# 0                                         James Cameron
# 1                                        Gore Verbinski
# 2                                            Sam Mendes
# 3                                     Christopher Nolan
# 4                                           Doug Walker
# ...                                                 ...
# 9344                                      Ranjeet Gupta
# 9345  Raj & D.K Nitya Mehra Nikkhil Advani , Tannish...
# 9346                               Vikramaditya Motwane
# 9347                                       David Dhawan
# 9348                                   Indrajit Lankesh
#
#                actor_1_name      actor_2_name          actor_3_name  \
# 0               CCH Pounder  Joel David Moore             Wes Studi
# 1               Johnny Depp     Orlando Bloom        Jack Davenport
# 2           Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3                 Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4               Doug Walker        Rob Walker               unknown
# ...                     ...               ...                   ...
# 9344  Kulbhushan Kharbanda           Jagdeep       Shweta Bhardwaj
# 9345       Gulshan Devaiah       Sumeet Vyas          Saiyami Kher
# 9346           Anil Kapoor     Anurag Kashyap                   nan
# 9347          Varun Dhawan      Sara Ali Khan                   nan
# 9348          Richa Chadda   Pankaj Tripathi          Rajeev Pillai
#
#                                genres  \
# 0     Action Adventure Fantasy Sci-Fi
# 1            Action Adventure Fantasy
# 2           Action Adventure Thriller
# 3                     Action Thriller
# 4                         Documentary
# ...                               ...
# 9344                              nan
# 9345                     Comedy Drama
# 9346        Comedy Action Drama Crime
# 9347                     Comedy Drama
# 9348                    Drama Romance
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 9344                                 omprakash zindabad
# 9345                                           unpaused
# 9346                                           ak vs ak
# 9347                                       coolie no. 1
# 9348                                           shakeela
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 9344  Kulbhushan Kharbanda  Jagdeep  Shweta Bhardwaj...
# 9345  Gulshan Devaiah  Sumeet Vyas  Saiyami Kher  Ra...
# 9346  Anil Kapoor  Anurag Kashyap nan Vikramaditya M...
# 9347  Varun Dhawan  Sara Ali Khan nan David Dhawan C...
# 9348  Richa Chadda  Pankaj Tripathi  Rajeev Pillai I...
#
# [9349 rows x 7 columns]

# %%
final_df.to_csv('C:\\Users\\Ankan Dutta\\Desktop\\DTI\\datasets\\main_data.csv',index=False)
