# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %%
df=pd.read_csv("C:\\Users\\Ankan Dutta\\Desktop\\DTI\\datasets\\2007-2013 Data Set.csv")

# %%
df
# Out:
#              Title               Director  \
# 0             1971            Amrit Sagar
# 1          50 Lakh  Chandra Sekhar Yeleti
# 2         68 Pages       Sridhar Rangayan
# 3             A ag        Ram Gopal Varma
# 4      Aaja Nachle             Anil Mehta
# ..             ...                    ...
# 757    Bullet Raja       Tigmanshu Dhulia
# 758  R... Rajkumar             Prabhudeva
# 759        Jackpot          Kaizad Gustad
# 760  What the Fish          Gurmmet Singh
# 761        Dhoom 3  Vijay Krishna Acharya
#
#                                                   Cast                 Genre  \
# 0                Manoj Bajpai, Ravi Kishan, Manav Kaul                   War
# 1                         Pawan Malhotra, Mohit Chadda                   NaN
# 2           Mouli GangulY, Joy Sengupta, Jayati Bhatia          Social Drama
# 3    Amitabh Bachchan, Ajay Devgn, Sushmita Sen, Ni...      Action, Thriller
# 4    Madhuri Dixit, Akshaye Khanna, Kunal Kapoor, K...               Musical
# ..                                                 ...                   ...
# 757  Saif Ali Khan, Sonakshi Sinha, Jimmy Sheirgill...  Comedy/Crime/Romance
# 758  Shahid Kapoor, Sonakshi Sinha, Sonu Sood, Asra...        Action/Romance
# 759  Sachiin J Joshi, Naseeruddin Shah, sunny Leone...       Thriller/Comedy
# 760  Dimple Kapadia, Manu Rishi, Manjot Singh, Anan...                 Drama
# 761  Aamir Khan, Abhishek Bachchan, Katrina Kaif, U...                Action
#
#     Unnamed: 4
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 757        NaN
# 758        NaN
# 759        NaN
# 760        NaN
# 761        NaN
#
# [762 rows x 5 columns]

# %%
df_hin = df[['Title','Director','Cast','Genre']]

# %%
df_hin
# Out:
#              Title               Director  \
# 0             1971            Amrit Sagar
# 1          50 Lakh  Chandra Sekhar Yeleti
# 2         68 Pages       Sridhar Rangayan
# 3             A ag        Ram Gopal Varma
# 4      Aaja Nachle             Anil Mehta
# ..             ...                    ...
# 757    Bullet Raja       Tigmanshu Dhulia
# 758  R... Rajkumar             Prabhudeva
# 759        Jackpot          Kaizad Gustad
# 760  What the Fish          Gurmmet Singh
# 761        Dhoom 3  Vijay Krishna Acharya
#
#                                                   Cast                 Genre
# 0                Manoj Bajpai, Ravi Kishan, Manav Kaul                   War
# 1                         Pawan Malhotra, Mohit Chadda                   NaN
# 2           Mouli GangulY, Joy Sengupta, Jayati Bhatia          Social Drama
# 3    Amitabh Bachchan, Ajay Devgn, Sushmita Sen, Ni...      Action, Thriller
# 4    Madhuri Dixit, Akshaye Khanna, Kunal Kapoor, K...               Musical
# ..                                                 ...                   ...
# 757  Saif Ali Khan, Sonakshi Sinha, Jimmy Sheirgill...  Comedy/Crime/Romance
# 758  Shahid Kapoor, Sonakshi Sinha, Sonu Sood, Asra...        Action/Romance
# 759  Sachiin J Joshi, Naseeruddin Shah, sunny Leone...       Thriller/Comedy
# 760  Dimple Kapadia, Manu Rishi, Manjot Singh, Anan...                 Drama
# 761  Aamir Khan, Abhishek Bachchan, Katrina Kaif, U...                Action
#
# [762 rows x 4 columns]

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in c:\users\ankan dutta\appdata\local\programs\python\python311\lib\site-packages (1.7.7)
# Requirement already satisfied: requests in c:\users\ankan dutta\appdata\local\programs\python\python311\lib\site-packages (from tmdbv3api) (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ankan dutta\appdata\local\programs\python\python311\lib\site-packages (from requests->tmdbv3api) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ankan dutta\appdata\local\programs\python\python311\lib\site-packages (from requests->tmdbv3api) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ankan dutta\appdata\local\programs\python\python311\lib\site-packages (from requests->tmdbv3api) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ankan dutta\appdata\local\programs\python\python311\lib\site-packages (from requests->tmdbv3api) (2022.12.7)
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '28a4d63a51fd003a26ae5b50b3d0832d'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_hin['genres'] = df_hin['Title'].map(lambda x: get_genre(str(x)))

# %%
df_hin
# Out:
#              Title               Director  \
# 0             1971            Amrit Sagar
# 1          50 Lakh  Chandra Sekhar Yeleti
# 2         68 Pages       Sridhar Rangayan
# 3             A ag        Ram Gopal Varma
# 4      Aaja Nachle             Anil Mehta
# ..             ...                    ...
# 757    Bullet Raja       Tigmanshu Dhulia
# 758  R... Rajkumar             Prabhudeva
# 759        Jackpot          Kaizad Gustad
# 760  What the Fish          Gurmmet Singh
# 761        Dhoom 3  Vijay Krishna Acharya
#
#                                                   Cast                 Genre
# 0                Manoj Bajpai, Ravi Kishan, Manav Kaul                   War
# 1                         Pawan Malhotra, Mohit Chadda                   NaN
# 2           Mouli GangulY, Joy Sengupta, Jayati Bhatia          Social Drama
# 3    Amitabh Bachchan, Ajay Devgn, Sushmita Sen, Ni...      Action, Thriller
# 4    Madhuri Dixit, Akshaye Khanna, Kunal Kapoor, K...               Musical
# ..                                                 ...                   ...
# 757  Saif Ali Khan, Sonakshi Sinha, Jimmy Sheirgill...  Comedy/Crime/Romance
# 758  Shahid Kapoor, Sonakshi Sinha, Sonu Sood, Asra...        Action/Romance
# 759  Sachiin J Joshi, Naseeruddin Shah, sunny Leone...       Thriller/Comedy
# 760  Dimple Kapadia, Manu Rishi, Manjot Singh, Anan...                 Drama
# 761  Aamir Khan, Abhishek Bachchan, Katrina Kaif, U...                Action
#
# [762 rows x 4 columns]

# %%
df_hin = df_hin.rename(columns={'Director':'director_name'})

# %%
df_hin = df_hin.rename(columns={'Genre':'genres'})

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_hin['actor_1_name'] = df_hin['Cast'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_hin['actor_2_name'] = df_hin['Cast'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_hin['actor_3_name'] = df_hin['Cast'].map(lambda x: get_actor3(str(x)))

# %%
df_hin
# Out:
#              Title          director_name  \
# 0             1971            Amrit Sagar
# 1          50 Lakh  Chandra Sekhar Yeleti
# 2         68 Pages       Sridhar Rangayan
# 3             A ag        Ram Gopal Varma
# 4      Aaja Nachle             Anil Mehta
# ..             ...                    ...
# 757    Bullet Raja       Tigmanshu Dhulia
# 758  R... Rajkumar             Prabhudeva
# 759        Jackpot          Kaizad Gustad
# 760  What the Fish          Gurmmet Singh
# 761        Dhoom 3  Vijay Krishna Acharya
#
#                                                   Cast                genres  \
# 0                Manoj Bajpai, Ravi Kishan, Manav Kaul                   War
# 1                         Pawan Malhotra, Mohit Chadda                   NaN
# 2           Mouli GangulY, Joy Sengupta, Jayati Bhatia          Social Drama
# 3    Amitabh Bachchan, Ajay Devgn, Sushmita Sen, Ni...      Action, Thriller
# 4    Madhuri Dixit, Akshaye Khanna, Kunal Kapoor, K...               Musical
# ..                                                 ...                   ...
# 757  Saif Ali Khan, Sonakshi Sinha, Jimmy Sheirgill...  Comedy/Crime/Romance
# 758  Shahid Kapoor, Sonakshi Sinha, Sonu Sood, Asra...        Action/Romance
# 759  Sachiin J Joshi, Naseeruddin Shah, sunny Leone...       Thriller/Comedy
# 760  Dimple Kapadia, Manu Rishi, Manjot Singh, Anan...                 Drama
# 761  Aamir Khan, Abhishek Bachchan, Katrina Kaif, U...                Action
#
#          actor_1_name       actor_2_name      actor_3_name
# 0        Manoj Bajpai        Ravi Kishan        Manav Kaul
# 1      Pawan Malhotra       Mohit Chadda               NaN
# 2       Mouli GangulY       Joy Sengupta     Jayati Bhatia
# 3    Amitabh Bachchan         Ajay Devgn      Sushmita Sen
# 4       Madhuri Dixit     Akshaye Khanna      Kunal Kapoor
# ..                ...                ...               ...
# 757     Saif Ali Khan     Sonakshi Sinha   Jimmy Sheirgill
# 758     Shahid Kapoor     Sonakshi Sinha         Sonu Sood
# 759   Sachiin J Joshi   Naseeruddin Shah  sunny Leone[116]
# 760    Dimple Kapadia         Manu Rishi      Manjot Singh
# 761        Aamir Khan  Abhishek Bachchan      Katrina Kaif
#
# [762 rows x 7 columns]

# %%
df_hin = df_hin.rename(columns={'Title':'movie_title'})

# %%
new_df = df_hin.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df
# Out:
#              director_name      actor_1_name       actor_2_name  \
# 0              Amrit Sagar      Manoj Bajpai        Ravi Kishan
# 1    Chandra Sekhar Yeleti    Pawan Malhotra       Mohit Chadda
# 2         Sridhar Rangayan     Mouli GangulY       Joy Sengupta
# 3          Ram Gopal Varma  Amitabh Bachchan         Ajay Devgn
# 4               Anil Mehta     Madhuri Dixit     Akshaye Khanna
# ..                     ...               ...                ...
# 757       Tigmanshu Dhulia     Saif Ali Khan     Sonakshi Sinha
# 758             Prabhudeva     Shahid Kapoor     Sonakshi Sinha
# 759          Kaizad Gustad   Sachiin J Joshi   Naseeruddin Shah
# 760          Gurmmet Singh    Dimple Kapadia         Manu Rishi
# 761  Vijay Krishna Acharya        Aamir Khan  Abhishek Bachchan
#
#          actor_3_name                genres    movie_title
# 0          Manav Kaul                   War           1971
# 1                 NaN                   NaN        50 Lakh
# 2       Jayati Bhatia          Social Drama       68 Pages
# 3        Sushmita Sen      Action, Thriller           A ag
# 4        Kunal Kapoor               Musical    Aaja Nachle
# ..                ...                   ...            ...
# 757   Jimmy Sheirgill  Comedy/Crime/Romance    Bullet Raja
# 758         Sonu Sood        Action/Romance  R... Rajkumar
# 759  sunny Leone[116]       Thriller/Comedy        Jackpot
# 760      Manjot Singh                 Drama  What the Fish
# 761      Katrina Kaif                Action        Dhoom 3
#
# [762 rows x 6 columns]

# %%
print(new_df.dtypes)
# Out:
# director_name    object
# actor_1_name     object
# actor_2_name     object
# actor_3_name     object
# genres           object
# movie_title      object
# dtype: object

# %%
new_df
# Out:
#              director_name      actor_1_name       actor_2_name  \
# 0              Amrit Sagar      Manoj Bajpai        Ravi Kishan
# 1    Chandra Sekhar Yeleti    Pawan Malhotra       Mohit Chadda
# 2         Sridhar Rangayan     Mouli GangulY       Joy Sengupta
# 3          Ram Gopal Varma  Amitabh Bachchan         Ajay Devgn
# 4               Anil Mehta     Madhuri Dixit     Akshaye Khanna
# ..                     ...               ...                ...
# 757       Tigmanshu Dhulia     Saif Ali Khan     Sonakshi Sinha
# 758             Prabhudeva     Shahid Kapoor     Sonakshi Sinha
# 759          Kaizad Gustad   Sachiin J Joshi   Naseeruddin Shah
# 760          Gurmmet Singh    Dimple Kapadia         Manu Rishi
# 761  Vijay Krishna Acharya        Aamir Khan  Abhishek Bachchan
#
#          actor_3_name                genres    movie_title
# 0          Manav Kaul                   War           1971
# 1                 NaN                   NaN        50 Lakh
# 2       Jayati Bhatia          Social Drama       68 Pages
# 3        Sushmita Sen      Action, Thriller           A ag
# 4        Kunal Kapoor               Musical    Aaja Nachle
# ..                ...                   ...            ...
# 757   Jimmy Sheirgill  Comedy/Crime/Romance    Bullet Raja
# 758         Sonu Sood        Action/Romance  R... Rajkumar
# 759  sunny Leone[116]       Thriller/Comedy        Jackpot
# 760      Manjot Singh                 Drama  What the Fish
# 761      Katrina Kaif                Action        Dhoom 3
#
# [762 rows x 6 columns]

# %%
for column in ['actor_1_name', 'actor_2_name', 'actor_3_name', 'director_name', 'genres']:
    for i in range(len(new_df)):
        new_df.at[i, column] = str(new_df.at[i, column])

new_df['comb'] = new_df['actor_1_name'] + ' ' + new_df['actor_2_name'] + ' ' + new_df['actor_3_name'] + ' ' + new_df['director_name'] + ' ' + new_df['genres']

# %%
new_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      8
# comb             0
# dtype: int64

# %%
new_df22 = new_df.dropna(how='any')

# %%
new_df22.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df22['movie_title'] = new_df22['movie_title'].str.lower()
# Out:
# C:\Users\Ankan Dutta\AppData\Local\Temp\ipykernel_21880\2732328091.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df22['movie_title'] = new_df22['movie_title'].str.lower()

# %%
new_df22
# Out:
#              director_name      actor_1_name       actor_2_name  \
# 0              Amrit Sagar      Manoj Bajpai        Ravi Kishan
# 1    Chandra Sekhar Yeleti    Pawan Malhotra       Mohit Chadda
# 2         Sridhar Rangayan     Mouli GangulY       Joy Sengupta
# 3          Ram Gopal Varma  Amitabh Bachchan         Ajay Devgn
# 4               Anil Mehta     Madhuri Dixit     Akshaye Khanna
# ..                     ...               ...                ...
# 757       Tigmanshu Dhulia     Saif Ali Khan     Sonakshi Sinha
# 758             Prabhudeva     Shahid Kapoor     Sonakshi Sinha
# 759          Kaizad Gustad   Sachiin J Joshi   Naseeruddin Shah
# 760          Gurmmet Singh    Dimple Kapadia         Manu Rishi
# 761  Vijay Krishna Acharya        Aamir Khan  Abhishek Bachchan
#
#          actor_3_name                genres    movie_title  \
# 0          Manav Kaul                   War           1971
# 1                 nan                   nan        50 lakh
# 2       Jayati Bhatia          Social Drama       68 pages
# 3        Sushmita Sen      Action, Thriller           a ag
# 4        Kunal Kapoor               Musical    aaja nachle
# ..                ...                   ...            ...
# 757   Jimmy Sheirgill  Comedy/Crime/Romance    bullet raja
# 758         Sonu Sood        Action/Romance  r... rajkumar
# 759  sunny Leone[116]       Thriller/Comedy        jackpot
# 760      Manjot Singh                 Drama  what the fish
# 761      Katrina Kaif                Action        dhoom 3
#
#                                                   comb
# 0    Manoj Bajpai Ravi Kishan Manav Kaul Amrit Saga...
# 1    Pawan Malhotra Mohit Chadda nan Chandra Sekhar...
# 2    Mouli GangulY Joy Sengupta Jayati Bhatia Sridh...
# 3    Amitabh Bachchan Ajay Devgn Sushmita Sen Ram G...
# 4    Madhuri Dixit Akshaye Khanna Kunal Kapoor Anil...
# ..                                                 ...
# 757  Saif Ali Khan Sonakshi Sinha Jimmy Sheirgill T...
# 758  Shahid Kapoor Sonakshi Sinha Sonu Sood Prabhud...
# 759  Sachiin J Joshi Naseeruddin Shah sunny Leone[1...
# 760  Dimple Kapadia Manu Rishi Manjot Singh Gurmmet...
# 761  Aamir Khan Abhishek Bachchan Katrina Kaif Vija...
#
# [754 rows x 7 columns]

# %%
old_df = pd.read_csv('C:\\Users\\Ankan Dutta\\Desktop\\DTI\\datasets\\main_data.csv')

# %%
old_df
# Out:
#           director_name     actor_1_name        actor_2_name  \
# 0         James Cameron      CCH Pounder    Joel David Moore
# 1        Gore Verbinski      Johnny Depp       Orlando Bloom
# 2            Sam Mendes  Christoph Waltz        Rory Kinnear
# 3     Christopher Nolan        Tom Hardy      Christian Bale
# 4           Doug Walker      Doug Walker          Rob Walker
# ...                 ...              ...                 ...
# 7131  Dharan Mandarayar  Sonali Kulkarni        Amardeep Jha
# 7132         Mohit Suri   Kangana Ranaut        Shiney Ahuja
# 7133   Nasseruddin Shah     Ayesha Takia  Konkona Sen Sharma
# 7134       Sanjay Gupta      Sanjay Dutt        John Abraham
# 7135     Tanuja Chandra     Sushmita Sen        Shiney Ahuja
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 7131        Shameem Shaikh                            Drama
# 7132                   NaN           Drama, Romance, Social
# 7133          Paresh Rawal                            Drama
# 7134            Lara Dutta                         Thriller
# 7135                   NaN                            Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 7131                                      white rainbow
# 7132                                       woh lamhe...
# 7133                              yun hota toh kya hota
# 7134                                              zinda
# 7135                                     zindaggi rocks
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 7131  Sonali Kulkarni Amardeep Jha Shameem Shaikh Dh...
# 7132  Kangana Ranaut Shiney Ahuja nan Mohit Suri Dra...
# 7133  Ayesha Takia Konkona Sen Sharma Paresh Rawal N...
# 7134  Sanjay Dutt John Abraham Lara Dutta Sanjay Gup...
# 7135  Sushmita Sen Shiney Ahuja nan Tanuja Chandra D...
#
# [7136 rows x 7 columns]

# %%
final_df = old_df.append(new_df22,ignore_index=True)
# Out:
# C:\Users\Ankan Dutta\AppData\Local\Temp\ipykernel_21880\1166909226.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = old_df.append(new_df22,ignore_index=True)

# %%
final_df
# Out:
#               director_name     actor_1_name       actor_2_name  \
# 0             James Cameron      CCH Pounder   Joel David Moore
# 1            Gore Verbinski      Johnny Depp      Orlando Bloom
# 2                Sam Mendes  Christoph Waltz       Rory Kinnear
# 3         Christopher Nolan        Tom Hardy     Christian Bale
# 4               Doug Walker      Doug Walker         Rob Walker
# ...                     ...              ...                ...
# 7885       Tigmanshu Dhulia    Saif Ali Khan     Sonakshi Sinha
# 7886             Prabhudeva    Shahid Kapoor     Sonakshi Sinha
# 7887          Kaizad Gustad  Sachiin J Joshi   Naseeruddin Shah
# 7888          Gurmmet Singh   Dimple Kapadia         Manu Rishi
# 7889  Vijay Krishna Acharya       Aamir Khan  Abhishek Bachchan
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 7885       Jimmy Sheirgill             Comedy/Crime/Romance
# 7886             Sonu Sood                   Action/Romance
# 7887      sunny Leone[116]                  Thriller/Comedy
# 7888          Manjot Singh                            Drama
# 7889          Katrina Kaif                           Action
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 7885                                        bullet raja
# 7886                                      r... rajkumar
# 7887                                            jackpot
# 7888                                      what the fish
# 7889                                            dhoom 3
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 7885  Saif Ali Khan Sonakshi Sinha Jimmy Sheirgill T...
# 7886  Shahid Kapoor Sonakshi Sinha Sonu Sood Prabhud...
# 7887  Sachiin J Joshi Naseeruddin Shah sunny Leone[1...
# 7888  Dimple Kapadia Manu Rishi Manjot Singh Gurmmet...
# 7889  Aamir Khan Abhishek Bachchan Katrina Kaif Vija...
#
# [7890 rows x 7 columns]

# %%
final_df.to_csv('C:\\Users\\Ankan Dutta\\Desktop\\DTI\\datasets\\main_data.csv',index=False)
